# %% [markdown]
# # Lab Instructions
#
# You have been hired by a record executive to design a guaranteed smash hit song based on data.  The exec has decided that if you make a song that has all the most popular features of recent songs then it will definitely be a hit.  So if - for example - the most common key in the Spotify data is C# then we would want the song we are designing to also be in C#.  If a "typical" value of BPM is between 120 and 130 then we would want the song we are designing to also have a tempo between 120 and 130 BMP.
#
# Visualize and describe the distribution of:
# * BPM
# * Key
# * Mode
# * Danceability
# * Energy
# * Speechiness
# * Acousticness
#
# Based on your visualizations and calculations, what values for each of these features would make a song a guaranteed smash hit?  For quantitative features, you should propose a range of values.
#
# Use a large language model to help you write code to identify if there are any songs in the Spotify dataset that meet all of the criteria we determined.  What is/are the artist(s) and title(s) of the song?  Were any of these songs actually popular?
#
# Pick a song that you know was a smash hit. How do the values of BPM, key, mode, danceability, etc. compare to other songs?
#
# **Hint:**  Import the Spotify data using `df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')`.

# %%
import pandas as pd

df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')

df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                147  141381703                  43  ...  125   B  Major
# 1                 48  133716286                  48  ...   92  C#  Major
# 2                113  140003974                  94  ...  138   F  Major
# 3                100  800840817                 116  ...  170   A  Major
# 4                 50  303236322                  84  ...  144   A  Minor
#
#   danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0             80         89       83             31                   0
# 1             71         61       74              7                   0
# 2             51         32       53             17                   0
# 3             55         58       72             11                   0
# 4             65         23       80             14                  63
#
#    liveness_%  speechiness_%
# 0           8              4
# 1          10              4
# 2          31              6
# 3          11             15
# 4          11              6
#
# [5 rows x 24 columns]

# %%
df['bpm'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["bpm"].plot(kind="hist", bins=20, title="Distribution of BPM")
# Out:
# <Axes: title={'center': 'Distribution of BPM'}, ylabel='Frequency'>

# %%
df["danceability_%"].plot(kind="hist", bins=20, title="Distribution of Danceability")
# Out:
# <Axes: title={'center': 'Distribution of Danceability'}, ylabel='Frequency'>

# %%
df["energy_%"].plot(kind="hist", bins=20, title="Distribution of Energy")
# Out:
# <Axes: title={'center': 'Distribution of Energy'}, ylabel='Frequency'>

# %%
df["valence_%"].plot(kind="hist", bins=20, title="Distribution of Valence")
# Out:
# <Axes: title={'center': 'Distribution of Valence'}, ylabel='Frequency'>

# %%
df["mode"].value_counts().plot(kind="pie", autopct="%1.1f%%", title="Mode Distribution")
# Out:
# <Axes: title={'center': 'Mode Distribution'}, ylabel='count'>

# %%
df["key"].value_counts().plot(kind="bar", title="Key Distribution")
# Out:
# <Axes: title={'center': 'Key Distribution'}, xlabel='key'>

# %%
df["speechiness_%"].value_counts().plot(kind="bar", title="Distribution of Speechiness")
# Out:
# <Axes: title={'center': 'Distribution of Speechiness'}, xlabel='speechiness_%'>

# %%
df["acousticness_%"].value_counts().plot(kind="bar", title="Distribution of Acousticness")
# Out:
# <Axes: title={'center': 'Distribution of Acousticness'}, xlabel='acousticness_%'>

# %%
df['bpm'].describe()
# Out:
# count    953.000000
# mean     122.540399
# std       28.057802
# min       65.000000
# 25%      100.000000
# 50%      121.000000
# 75%      140.000000
# max      206.000000
# Name: bpm, dtype: float64

# %%
df["danceability_%"].describe()
# Out:
# count    953.00000
# mean      66.96957
# std       14.63061
# min       23.00000
# 25%       57.00000
# 50%       69.00000
# 75%       78.00000
# max       96.00000
# Name: danceability_%, dtype: float64

# %%
df["energy_%"].describe()
# Out:
# count    953.000000
# mean      64.279119
# std       16.550526
# min        9.000000
# 25%       53.000000
# 50%       66.000000
# 75%       77.000000
# max       97.000000
# Name: energy_%, dtype: float64

# %%
df["valence_%"].describe()
# Out:
# count    953.000000
# mean      51.431270
# std       23.480632
# min        4.000000
# 25%       32.000000
# 50%       51.000000
# 75%       70.000000
# max       97.000000
# Name: valence_%, dtype: float64

# %%
df["speechiness_%"].describe()
# Out:
# count    953.000000
# mean      10.131165
# std        9.912888
# min        2.000000
# 25%        4.000000
# 50%        6.000000
# 75%       11.000000
# max       64.000000
# Name: speechiness_%, dtype: float64

# %%
df["acousticness_%"].describe()
# Out:
# count    953.000000
# mean      27.057712
# std       25.996077
# min        0.000000
# 25%        6.000000
# 50%       18.000000
# 75%       43.000000
# max       97.000000
# Name: acousticness_%, dtype: float64

# %%
df["mode"].describe()
# Out:
# count       953
# unique        2
# top       Major
# freq        550
# Name: mode, dtype: object

# %%
df["key"].describe()
# Out:
# count     858
# unique     11
# top        C#
# freq      120
# Name: key, dtype: object

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
df['mode'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['key'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['mode'].value_counts()
# Out:
# mode
# Major    550
# Minor    403
# Name: count, dtype: int64

# %%
df['key'].value_counts()
# Out:
# key
# C#    120
# G      96
# G#     91
# F      89
# B      81
# D      81
# A      75
# F#     73
# E      62
# A#     57
# D#     33
# Name: count, dtype: int64

# %%
filtered_df = df.loc[(df['bpm'] >= 85) & (df['bpm'] <= 140) & (df['mode'] == 'Minor') & (df['key'] == 'A') ]

filtered_df.head()
# Out:
#               track_name        artist(s)_name  artist_count  released_year  \
# 93      Donï¿½ï¿½ï¿½t Bl          Taylor Swift             1           2017
# 120                 LUNA  Junior H, Peso Pluma             2           2023
# 131                  OMG              NewJeans             1           2023
# 150       Mi Bello Angel         Natanael Cano             1           2023
# 159  Under The Influence           Chris Brown             1           2019
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 93               11             8                  4875                 23
# 120               6            22                   201                 11
# 131               1             2                  1783                 27
# 150               6            30                    86                  8
# 159              10             4                  3859                 26
#
#        streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# 93   685032533                  19  ...  136   A  Minor             62
# 120   55842345                  19  ...  128   A  Minor             75
# 131  430977451                  26  ...  127   A  Minor             80
# 150   31873544                   7  ...  128   A  Minor             81
# 159  929964809                 133  ...  117   A  Minor             73
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 93          19       53             11                   0           6
# 120         79       63             33                   0          15
# 131         74       77             36                   0          11
# 150         90       77              1                   0           9
# 159         31       69              6                   0          11
#
#      speechiness_%
# 93               4
# 120              4
# 131              4
# 150              5
# 159              4
#
# [5 rows x 24 columns]

# %% [markdown]
# After applying the smash hit criteria, we found that only a small number of songs matched all conditions. This shows that while certain ranges (like BPM 85–140) and features (Minor mode, Key A) are common, hit songs can still succeed outside these boundaries.
